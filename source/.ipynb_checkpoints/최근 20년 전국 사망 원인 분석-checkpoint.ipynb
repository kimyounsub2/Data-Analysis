# %% [markdown]
# * 103항목, 236항목, 영유아 67항목은 사망원인을 효과적으로 집계하기 위한 제표체계입니다.
# - 103항목은 세계보건기구(WHO)의 권고에 따라 국가간 비교가 가능하도록 사망원인을 103개 항목으로 제표한 항목

# %%
import pandas as pd

# %%
# 전국 사망원인 103항목
file = pd.read_csv('C:/Users/김윤섭/Documents/data/지역별 사망 원인 분석.csv' ,engine='python')

# %%
file.head(n=3)
# Out:
#   사망원인별(103항목) 성별    시도별       항목 단위    1983 년    1984 년    1985 년    1986 년  \
# 0            계  계     전국  사망자수[명]  명  254563.0  236445.0  240418.0  239256.0
# 1            계  계  서울특별시  사망자수[명]  명   33422.0   32932.0   34927.0   34772.0
# 2            계  계  부산광역시  사망자수[명]  명   14788.0   14516.0   15088.0   14780.0
#
#      1987 년     ...       2012 년  2013 년  2014 년  2015 년  2016 년  2017 년  \
# 0  243504.0     ...       267221  266257  267692  275895  280827  285534
# 1   35654.0     ...        41514   42063   42153   43053   43540   42932
# 2   15242.0     ...        20534   20096   20230   20820   21074   21434
#
#    2018 년  2019 년  2020 년  Unnamed: 43
# 0  298820  295110  304948          NaN
# 1   45219   43829   45522          NaN
# 2   22570   22260   22950          NaN
#
# [3 rows x 44 columns]

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 44 columns):
# 사망원인별(103항목)    1080 non-null object
# 성별              1080 non-null object
# 시도별             1080 non-null object
# 항목              1080 non-null object
# 단위              1080 non-null object
# 1983 년          840 non-null float64
# 1984 년          840 non-null float64
# 1985 년          840 non-null float64
# 1986 년          900 non-null float64
# 1987 년          900 non-null float64
# 1988 년          900 non-null float64
# 1989 년          960 non-null float64
# 1990 년          960 non-null float64
# 1991 년          960 non-null float64
# 1992 년          960 non-null float64
# 1993 년          960 non-null float64
# 1994 년          960 non-null float64
# 1995 년          960 non-null float64
# 1996 년          960 non-null float64
# 1997 년          1020 non-null float64
# 1998 년          1020 non-null float64
# 1999 년          1020 non-null float64
# ...

# %%
file.shape
# Out:
# (1080, 44)

# %%
file['사망원인별(103항목)'].unique()
# Out:
# array(['계', '특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)', '신생물 (C00-D48)',
#        '혈액 및 조혈기관질환과 면역메커니즘을 침범하는 특정장애 (D50-D89)',
#        '내분비, 영양 및 대사 질환 (E00-E88)', '정신 및 행동장애 (F01-F99)',
#        '신경계통의 질환 (G00-G98)', '눈 및 눈부속기의 질환 (H00-H57)',
#        '귀 및 유돌의 질환 (H60-H93)', '순환계통 질환 (I00-I99)',
#        '호흡계통의 질환 (J00-J98,U04)', '소화계통의 질환 (K00-K92)',
#        '피부 및 피하조직의 질환 (L00-L98)', '근골격계통 및 결합 조직의 질환 (M00-M99)',
#        '비뇨생식계통의 질환 (N00-N98)', '임신, 출산 및 산후기 (O00-O99)',
#        '출생전후기에 기원한 특정병태 (P00-P96)', '선천 기형, 변형 및 염색체 이상 (Q00-Q99)',
#        '달리 분류되지 않은 증상, 징후 (R00-R99)', '질병이환 및 사망의 외인 (V01-Y89)'],
#       dtype=object)

# %%
file['시도별'].unique()
# Out:
# array(['전국', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시',
#        '울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도',
#        '경상북도', '경상남도', '제주도'], dtype=object)

# %%
test = file[file['성별'] == '계']

# %%
A00_B99 = test[test['사망원인별(103항목)'] == '특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)']

# %%
A00_B99
# Out:
#                                 사망원인별(103항목) 성별      시도별       항목 단위   1983 년  \
# 54  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  계       전국  사망자수[명]  명  10560.0
# 55  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  계    서울특별시  사망자수[명]  명   1293.0
# 56  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  계    부산광역시  사망자수[명]  명    790.0
# 57  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  계    대구광역시  사망자수[명]  명    302.0
# 58  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  계    인천광역시  사망자수[명]  명    244.0
# 59  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  계    광주광역시  사망자수[명]  명      NaN
# 60  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  계    대전광역시  사망자수[명]  명      NaN
# 61  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  계    울산광역시  사망자수[명]  명      NaN
# 62  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  계  세종특별자치시  사망자수[명]  명      NaN
# 63  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  계      경기도  사망자수[명]  명    877.0
# 64  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  계      강원도  사망자수[명]  명    627.0
# ...

# %%
A00_B99_1 = A00_B99.drop(['성별','항목', '단위','Unnamed: 43'], axis=1)

# %%
A00_B99_1.head()
# Out:
#                                 사망원인별(103항목)    시도별   1983 년  1984 년  1985 년  \
# 54  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)     전국  10560.0  9672.0  8551.0
# 55  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  서울특별시   1293.0  1241.0  1225.0
# 56  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  부산광역시    790.0   710.0   623.0
# 57  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  대구광역시    302.0   281.0   271.0
# 58  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  인천광역시    244.0   271.0   220.0
#
#     1986 년  1987 년  1988 년  1989 년  1990 년   ...    2011 년  2012 년  2013 년  \
# 54  7690.0  7127.0  6295.0  5802.0  5687.0   ...    6766.0    7106    6683
# 55  1172.0  1206.0  1155.0   999.0  1043.0   ...    1101.0    1090    1091
# 56   659.0   633.0   580.0   571.0   515.0   ...     513.0     575     495
# 57   235.0   211.0   209.0   198.0   180.0   ...     340.0     328     313
# 58   251.0   208.0   220.0   161.0   179.0   ...     308.0     301     292
#
# ...

# %%
A00_B99_2 = A00_B99_1.melt(id_vars=['사망원인별(103항목)','시도별'])

# %%
A00_B99_2.head()
# Out:
#                                사망원인별(103항목)    시도별 variable    value
# 0  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)     전국   1983 년  10560.0
# 1  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  서울특별시   1983 년   1293.0
# 2  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  부산광역시   1983 년    790.0
# 3  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  대구광역시   1983 년    302.0
# 4  특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)  인천광역시   1983 년    244.0

# %%
import seaborn as sns

# %%
### 그래프 한글 깨질때
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
# - 기호 깨지는것 방지
plt.rcParams['axes.unicode_minus'] = False

f_path = "C:/Windows/Fonts/malgun.ttf"

font_name = font_manager.FontProperties(fname = f_path).get_name()
rc('font', family=font_name)

# %%
plt.figure(figsize = (30, 10))
plt.title('전국 특정 감염성 및 기생충성 질환 (A00-B99, U07.1, U07.2)')
sns.barplot(data = A00_B99_2 , x = 'variable', y = 'value')
# Out:
# C:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
